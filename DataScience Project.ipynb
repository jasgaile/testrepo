# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jasmine Gaile Sy Robrigado** Software Engineer

# %% [markdown]
# *I'm interested in Data Science because I want to be an Software Engineer. This is the field I'm always interested since I was a kid*

# %% [markdown]
# ### One plus two in cell 5 is equal to three.

# %%
1+2
# Out:
# 3

# %% [markdown]
# *
# *
# *
#
# 1.
# 2.
# 3.
#
# | Country Name | Capital | Region |
# | -------------| ------- | ------ |
# |              |         |        |
#
# [Skills Network](https://skills.network/)
#
# LOGO: ![This is the skills network logo](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png)
